# %%
import dash
import dash_core_components as dcc
import dash_html_components as html

# %%
h1_object = html.H1('hello world')

# %%
dcc.Graph(figure={'data': [{'x': [1, 2, 3], 'y': [4, 55, 6]}], 'layout': {}})
# Out:
# Graph(figure={'data': [{'x': [1, 2, 3], 'y': [4, 55, 6]}], 'foobar': {}})
