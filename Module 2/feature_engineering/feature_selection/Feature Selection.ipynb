# %% [markdown]
# # Feature Selection
#
# Feature selection… is the process of selecting a subset of relevant features for use in model construction

# %% [markdown]
# ## Top reasons to use feature selection are:
# * It enables the machine learning algorithm to train faster.
# * It reduces the complexity of a model and makes it easier to interpret.
# * It improves the accuracy of a model if the right subset is chosen.
# * It reduces overfitting.

# %% [markdown]
# ## Types of Feature Selection
#
# * Filter Methods
# * Wrapper Methods
# * Embedded Methods

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from sklearn import metrics

columns = "age sex bmi map tc ldl hdl tch ltg glu y".split() # Declare the columns names
diabetes = datasets.load_diabetes() # Call the diabetes dataset from sklearn
df = pd.read_csv('diabetes.tab.txt', sep='\t', lineterminator='\n')
df.columns= columns
features = df.iloc[:,:-1]
target = df.y

# %%
features['female'] = pd.get_dummies(features['sex'],drop_first=True)
features.drop(columns=['sex'], inplace=True)

# %%
features.head()
# Out:
#    age   bmi    map   tc    ldl   hdl  tch     ltg  glu  female
# 0   59  32.1  101.0  157   93.2  38.0  4.0  4.8598   87       1
# 1   48  21.6   87.0  183  103.2  70.0  3.0  3.8918   69       0
# 2   72  30.5   93.0  156   93.6  41.0  4.0  4.6728   85       1
# 3   24  25.3   84.0  198  131.4  40.0  5.0  4.8903   89       0
# 4   50  23.0  101.0  192  125.4  52.0  4.0  4.2905   80       0

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=32,test_size=0.2)

# %% [markdown]
# If you have multiple predictor variables in a regression, here is advice from Tabachnick & Fidell, Using Multivariate Statistics (k is the number of predictors)
#
# a minimum N > 50 + (8*k) for tests of multiple R
#
# a minimum N > 104 + k for tests of individual predictors

# %%
from sklearn import preprocessing
from sklearn import pipeline

scaler = preprocessing.StandardScaler()

# %%
scaler.fit(features.iloc[:,:-1])
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaler.fit(X_train.iloc[:,:-1])
features_scaled_train = pd.DataFrame(scaler.transform(X_train.iloc[:,:-1]), columns=X_train.columns[:-1], index=X_train.index)

features_scaled_train['female']= X_train.female

features_scaled_train.head()
# Out:
#           age       bmi       map        tc       ldl       hdl       tch  \
# 268  1.367551  1.826023  1.462079  0.370605  0.728718 -1.102722  1.502515
# 170  0.529451 -0.424891 -0.767296 -0.331690 -0.354292  1.230277 -0.826539
# 384  0.758024 -0.625468  0.095688  1.859471  1.747264  0.685910 -0.050188
# 118 -1.146749 -0.224315  0.527180  0.426789  0.780290 -0.869422  0.726164
# 27  -0.461031  1.224293 -0.839211 -0.921618 -0.940923  0.219311 -0.826539
#
#           ltg       glu  female
# 268  0.619668  1.542137       1
# 170 -1.986232 -0.388269       1
# 384  0.511034 -0.826997       1
# 118  0.439618  1.191154       1
# 27  -0.319121  0.840171       0

# %%
X_test.head()
# Out:
#      age   bmi   map   tc    ldl   hdl  tch     ltg  glu  female
# 149   35  25.9  81.0  174  102.4  31.0  6.0  5.3132   82       1
# 314   42  30.1  91.0  182  114.8  49.0  4.0  4.5109   82       0
# 214   57  23.3  88.0  155   63.6  78.0  2.0  4.2047   78       0
# 95    29  21.0  71.0  156   97.0  38.0  4.0  4.6540   90       0
# 19    41  24.7  83.0  187  108.2  60.0  3.0  4.5433   78       0

# %%
features_scaled_test = pd.DataFrame(scaler.transform(X_test.iloc[:,:-1]), columns=X_test.columns[:-1], index=X_test.index)

features_scaled_test['female']= X_test.female

features_scaled_test.head()
# Out:
#           age       bmi       map        tc       ldl       hdl       tch  \
# 149 -0.994367 -0.112883 -0.983042 -0.472149 -0.463883 -1.491555  1.502515
# 314 -0.461031  0.823140 -0.263889 -0.247415 -0.064200 -0.091756 -0.050188
# 214  0.681833 -0.692327 -0.479634 -1.005894 -1.714502  2.163476 -1.602891
# 95  -1.451512 -1.204911 -1.702195 -0.977802 -0.637938 -0.947188 -0.050188
# 19  -0.537221 -0.380319 -0.839211 -0.106956 -0.276934  0.763677 -0.826539
#
#           ltg       glu  female
# 149  1.281676 -0.826997       1
# 314 -0.234103 -0.826997       0
# 214 -0.812604 -1.177980       0
# 95   0.036255 -0.125031       0
# 19  -0.172890 -1.177980       0

# %%
poly = preprocessing.PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)
features_64_train = pd.DataFrame(poly.fit_transform(features_scaled_train), columns=poly.get_feature_names(features_scaled_train.columns))
features_64_train.head()
# Out:
#         age       bmi       map        tc       ldl       hdl       tch  \
# 0  1.367551  1.826023  1.462079  0.370605  0.728718 -1.102722  1.502515
# 1  0.529451 -0.424891 -0.767296 -0.331690 -0.354292  1.230277 -0.826539
# 2  0.758024 -0.625468  0.095688  1.859471  1.747264  0.685910 -0.050188
# 3 -1.146749 -0.224315  0.527180  0.426789  0.780290 -0.869422  0.726164
# 4 -0.461031  1.224293 -0.839211 -0.921618 -0.940923  0.219311 -0.826539
#
#         ltg       glu  female    ...        tch^2   tch ltg   tch glu  \
# 0  0.619668  1.542137     1.0    ...     2.257552  0.931061  2.317084
# 1 -1.986232 -0.388269     1.0    ...     0.683168  1.641700  0.320919
# 2  0.511034 -0.826997     1.0    ...     0.002519 -0.025648  0.041505
# 3  0.439618  1.191154     1.0    ...     0.527314  0.319235  0.864973
# 4 -0.319121  0.840171     0.0    ...     0.683168  0.263766 -0.694435
#
#    tch female     ltg^2   ltg glu  ltg female     glu^2  glu female  female^2
# 0    1.502515  0.383988  0.955613    0.619668  2.378187    1.542137       1.0
# 1   -0.826539  3.945119  0.771192   -1.986232  0.150752   -0.388269       1.0
# 2   -0.050188  0.261155 -0.422623    0.511034  0.683924   -0.826997       1.0
# 3    0.726164  0.193264  0.523653    0.439618  1.418849    1.191154       1.0
# 4   -0.000000  0.101838 -0.268117   -0.000000  0.705888    0.000000       0.0
#
# [5 rows x 65 columns]

# %%
pd.set_option('display.max_columns', 100)

# %%
features_64_train.head()
# Out:
#         age       bmi       map        tc       ldl       hdl       tch  \
# 0  1.367551  1.826023  1.462079  0.370605  0.728718 -1.102722  1.502515
# 1  0.529451 -0.424891 -0.767296 -0.331690 -0.354292  1.230277 -0.826539
# 2  0.758024 -0.625468  0.095688  1.859471  1.747264  0.685910 -0.050188
# 3 -1.146749 -0.224315  0.527180  0.426789  0.780290 -0.869422  0.726164
# 4 -0.461031  1.224293 -0.839211 -0.921618 -0.940923  0.219311 -0.826539
#
#         ltg       glu  female     age^2   age bmi   age map    age tc  \
# 0  0.619668  1.542137     1.0  1.870196  2.497180  1.999468  0.506821
# 1 -1.986232 -0.388269     1.0  0.280319 -0.224959 -0.406246 -0.175614
# 2  0.511034 -0.826997     1.0  0.574600 -0.474120  0.072534  1.409523
# 3  0.439618  1.191154     1.0  1.315032  0.257233 -0.604543 -0.489419
# 4 -0.319121  0.840171     0.0  0.212549 -0.564437  0.386902  0.424894
#
#     age ldl   age hdl   age tch   age ltg   age glu  age female     bmi^2  \
# 0  0.996559 -1.508028  2.054766  0.847428  2.108952    1.367551  3.334360
# 1 -0.187580  0.651371 -0.437612 -1.051613 -0.205569    0.529451  0.180533
# 2  1.324468  0.519936 -0.038044  0.387376 -0.626884    0.758024  0.391210
# 3 -0.894797  0.997008 -0.832727 -0.504132 -1.365955   -1.146749  0.050317
# 4  0.433794 -0.101109  0.381060  0.147125 -0.387345   -0.000000  1.498894
#
#     bmi map    bmi tc   bmi ldl   bmi hdl   bmi tch   bmi ltg   bmi glu  \
# 0  2.669791  0.676733  1.330656 -2.013595  2.743627  1.131528  2.815978
# 1  0.326017  0.140932  0.150536 -0.522734  0.351190  0.843933  0.164972
# 2 -0.059850 -1.163039 -1.092857 -0.429015  0.031391 -0.319635  0.517260
# 3 -0.118254 -0.095735 -0.175031  0.195024 -0.162889 -0.098613 -0.267194
# 4 -1.027441 -1.128331 -1.151966  0.268501 -1.011927 -0.390698  1.028616
#
#    bmi female     map^2    map tc   map ldl   map hdl   map tch   map ltg  \
# 0    1.826023  2.137676  0.541854  1.065444 -1.612267  2.196796  0.906004
# 1   -0.424891  0.588743  0.254505  0.271847 -0.943986  0.634200  1.524028
# 2   -0.625468  0.009156  0.177929  0.167192  0.065633 -0.004802  0.048900
# 3   -0.224315  0.277919  0.224994  0.411353 -0.458342  0.382819  0.231758
# 4    0.000000  0.704275  0.773432  0.789633 -0.184048  0.693641  0.267810
#
#     map glu  map female      tc^2    tc ldl    tc hdl    tc tch    tc ltg  \
# 0  2.254727    1.462079  0.137348  0.270067 -0.408674  0.556840  0.229652
# 1  0.297917   -0.767296  0.110018  0.117515 -0.408071  0.274155  0.658814
# 2 -0.079134    0.095688  3.457632  3.248986  1.275430 -0.093323  0.950252
# 3  0.627953    0.527180  0.182148  0.333019 -0.371059  0.309918  0.187624
# 4 -0.705081   -0.000000  0.849380  0.867172 -0.202121  0.761754  0.294108
#
#      tc glu  tc female     ldl^2   ldl hdl   ldl tch   ldl ltg   ldl glu  \
# 0  0.571524   0.370605  0.531030 -0.803573  1.094910  0.451563  1.123783
# 1  0.128785  -0.331690  0.125523 -0.435877  0.292836  0.703707  0.137561
# 2 -1.537777   1.859471  3.052930  1.198466 -0.087692  0.892911 -1.444982
# 3  0.508371   0.426789  0.608853 -0.678401  0.566618  0.343030  0.929446
# 4 -0.774317  -0.000000  0.885336 -0.206354  0.777710  0.300268 -0.790536
#
#    ldl female     hdl^2   hdl tch   hdl ltg   hdl glu  hdl female     tch^2  \
# 0    0.728718  1.215995 -1.656856 -0.683321 -1.700548   -1.102722  2.257552
# 1   -0.354292  1.513580 -1.016872 -2.443615 -0.477678    1.230277  0.683168
# 2    1.747264  0.470473 -0.034424  0.350523 -0.567246    0.685910  0.002519
# 3    0.780290  0.755894 -0.631343 -0.382214 -1.035616   -0.869422  0.527314
# 4   -0.000000  0.048097 -0.181269 -0.069987  0.184259    0.000000  0.683168
#
#     tch ltg   tch glu  tch female     ltg^2   ltg glu  ltg female     glu^2  \
# 0  0.931061  2.317084    1.502515  0.383988  0.955613    0.619668  2.378187
# 1  1.641700  0.320919   -0.826539  3.945119  0.771192   -1.986232  0.150752
# 2 -0.025648  0.041505   -0.050188  0.261155 -0.422623    0.511034  0.683924
# 3  0.319235  0.864973    0.726164  0.193264  0.523653    0.439618  1.418849
# 4  0.263766 -0.694435   -0.000000  0.101838 -0.268117   -0.000000  0.705888
#
#    glu female  female^2
# 0    1.542137       1.0
# 1   -0.388269       1.0
# 2   -0.826997       1.0
# 3    1.191154       1.0
# 4    0.000000       0.0

# %%
features_64_test = pd.DataFrame(poly.fit_transform(features_scaled_test), columns=poly.get_feature_names(features_scaled_test.columns))
features_64_test.head()
# Out:
#         age       bmi       map        tc       ldl       hdl       tch  \
# 0 -0.994367 -0.112883 -0.983042 -0.472149 -0.463883 -1.491555  1.502515
# 1 -0.461031  0.823140 -0.263889 -0.247415 -0.064200 -0.091756 -0.050188
# 2  0.681833 -0.692327 -0.479634 -1.005894 -1.714502  2.163476 -1.602891
# 3 -1.451512 -1.204911 -1.702195 -0.977802 -0.637938 -0.947188 -0.050188
# 4 -0.537221 -0.380319 -0.839211 -0.106956 -0.276934  0.763677 -0.826539
#
#         ltg       glu  female     age^2   age bmi   age map    age tc  \
# 0  1.281676 -0.826997     1.0  0.988765  0.112248  0.977504  0.469490
# 1 -0.234103 -0.826997     0.0  0.212549 -0.379493  0.121661  0.114066
# 2 -0.812604 -1.177980     0.0  0.464896 -0.472051 -0.327031 -0.685852
# 3  0.036255 -0.125031     0.0  2.106888  1.748944  2.470757  1.419291
# 4 -0.172890 -1.177980     0.0  0.288607  0.204315  0.450842  0.057459
#
#     age ldl   age hdl   age tch   age ltg   age glu  age female     bmi^2  \
# 0  0.461269  1.483153 -1.494051 -1.274456  0.822339   -0.994367  0.012743
# 1  0.029598  0.042302  0.023138  0.107929  0.381271   -0.000000  0.677560
# 2 -1.169004  1.475129 -1.092904 -0.554060 -0.803186    0.000000  0.479316
# 3  0.925974  1.374856  0.072848 -0.052624  0.181485   -0.000000  1.451811
# 4  0.148775 -0.410264  0.444035  0.092880  0.632836   -0.000000  0.144642
#
#     bmi map    bmi tc   bmi ldl   bmi hdl   bmi tch   bmi ltg   bmi glu  \
# 0  0.110969  0.053298  0.052365  0.168372 -0.169609 -0.144680  0.093354
# 1 -0.217217 -0.203657 -0.052846 -0.075528 -0.041312 -0.192700 -0.680735
# 2  0.332064  0.696407  1.186995 -1.497832  1.109724  0.562588  0.815547
# 3  2.050994  1.178165  0.768658  1.141278  0.060472 -0.043684  0.150652
# 4  0.319168  0.040677  0.105323 -0.290441  0.314349  0.065753  0.448008
#
#    bmi female     map^2    map tc   map ldl   map hdl   map tch   map ltg  \
# 0   -0.112883  0.966371  0.464142  0.456016  1.466261 -1.477035 -1.259941
# 1    0.000000  0.069637  0.065290  0.016942  0.024213  0.013244  0.061777
# 2   -0.000000  0.230049  0.482461  0.822334 -1.037678  0.768802  0.389753
# 3   -0.000000  2.897468  1.664409  1.085894  1.612300  0.085430 -0.061712
# 4   -0.000000  0.704275  0.089758  0.232406 -0.640886  0.693641  0.145091
#
#     map glu  map female      tc^2    tc ldl    tc hdl    tc tch    tc ltg  \
# 0  0.812973   -0.983042  0.222925  0.219022  0.704236 -0.709411 -0.605142
# 1  0.218235   -0.000000  0.061214  0.015884  0.022702  0.012417  0.057921
# 2  0.565000   -0.000000  1.011822  1.724606 -2.176227  1.612338  0.817393
# 3  0.212828   -0.000000  0.956096  0.623777  0.926163  0.049074 -0.035450
# 4  0.988574   -0.000000  0.011440  0.029620 -0.081680  0.088403  0.018492
#
#      tc glu  tc female     ldl^2   ldl hdl   ldl tch   ldl ltg   ldl glu  \
# 0  0.390466  -0.472149  0.215187  0.691906 -0.696990 -0.594547  0.383630
# 1  0.204611  -0.000000  0.004122  0.005891  0.003222  0.015029  0.053093
# 2  1.184923  -0.000000  2.939516 -3.709283  2.748159  1.393211  2.019649
# 3  0.122256  -0.000000  0.406965  0.604247  0.032017 -0.023128  0.079762
# 4  0.125992  -0.000000  0.076693 -0.211488  0.228897  0.047879  0.326223
#
#    ldl female     hdl^2   hdl tch   hdl ltg   hdl glu  hdl female     tch^2  \
# 0   -0.463883  2.224735 -2.241084 -1.911690  1.233511   -1.491555  2.257552
# 1   -0.000000  0.008419  0.004605  0.021480  0.075882   -0.000000  0.002519
# 2   -0.000000  4.680628 -3.467816 -1.758050 -2.548531    0.000000  2.569260
# 3   -0.000000  0.897166  0.047537 -0.034340  0.118428   -0.000000  0.002519
# 4   -0.000000  0.583202 -0.631209 -0.132032 -0.899596    0.000000  0.683168
#
#     tch ltg   tch glu  tch female     ltg^2   ltg glu  ltg female     glu^2  \
# 0  1.925737 -1.242576    1.502515  1.642693 -1.059942    1.281676  0.683924
# 1  0.011749  0.041505   -0.000000  0.054804  0.193603   -0.000000  0.683924
# 2  1.302516  1.888174   -0.000000  0.660326  0.957232   -0.000000  1.387637
# 3 -0.001820  0.006275   -0.000000  0.001314 -0.004533    0.000000  0.015633
# 4  0.142900  0.973647   -0.000000  0.029891  0.203661   -0.000000  1.387637
#
#    glu female  female^2
# 0   -0.826997       1.0
# 1   -0.000000       0.0
# 2   -0.000000       0.0
# 3   -0.000000       0.0
# 4   -0.000000       0.0

# %% [markdown]
# # Filter Methods
# Filter feature selection methods apply a statistical measure to assign a scoring to each feature. The features are ranked by the score and either selected to be kept or removed from the dataset. The methods are often univariate and consider the feature independently, or with regard to the dependent variable.

# %% [markdown]
# ![alt text](Filter_1.png)

# %% [markdown]
# **Examples:**
# * F-Test
# * Chi squared test
# * Information gain
# * Correlation coefficient scores

# %% [markdown]
# ![alt text](FS1.webp)

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
thresholder = VarianceThreshold(threshold=.5)

def variance_threshold_selector(data, threshold=0.5):
    selector = VarianceThreshold(threshold)
    selector.fit(data)
    return data[data.columns[selector.get_support(indices=True)]]

# %%
features_selected_train = variance_threshold_selector(features_64_train)

# %%
features_selected_train.head()
# Out:
#         age       bmi       map        tc       ldl       hdl       tch  \
# 0  1.367551  1.826023  1.462079  0.370605  0.728718 -1.102722  1.502515
# 1  0.529451 -0.424891 -0.767296 -0.331690 -0.354292  1.230277 -0.826539
# 2  0.758024 -0.625468  0.095688  1.859471  1.747264  0.685910 -0.050188
# 3 -1.146749 -0.224315  0.527180  0.426789  0.780290 -0.869422  0.726164
# 4 -0.461031  1.224293 -0.839211 -0.921618 -0.940923  0.219311 -0.826539
#
#         ltg       glu     age^2   age bmi   age map    age tc   age ldl  \
# 0  0.619668  1.542137  1.870196  2.497180  1.999468  0.506821  0.996559
# 1 -1.986232 -0.388269  0.280319 -0.224959 -0.406246 -0.175614 -0.187580
# 2  0.511034 -0.826997  0.574600 -0.474120  0.072534  1.409523  1.324468
# 3  0.439618  1.191154  1.315032  0.257233 -0.604543 -0.489419 -0.894797
# 4 -0.319121  0.840171  0.212549 -0.564437  0.386902  0.424894  0.433794
#
#     age hdl   age tch   age ltg   age glu     bmi^2   bmi map    bmi tc  \
# 0 -1.508028  2.054766  0.847428  2.108952  3.334360  2.669791  0.676733
# 1  0.651371 -0.437612 -1.051613 -0.205569  0.180533  0.326017  0.140932
# 2  0.519936 -0.038044  0.387376 -0.626884  0.391210 -0.059850 -1.163039
# 3  0.997008 -0.832727 -0.504132 -1.365955  0.050317 -0.118254 -0.095735
# 4 -0.101109  0.381060  0.147125 -0.387345  1.498894 -1.027441 -1.128331
#
#     bmi ldl   bmi hdl   bmi tch   bmi ltg   bmi glu     map^2    map tc  \
# 0  1.330656 -2.013595  2.743627  1.131528  2.815978  2.137676  0.541854
# 1  0.150536 -0.522734  0.351190  0.843933  0.164972  0.588743  0.254505
# 2 -1.092857 -0.429015  0.031391 -0.319635  0.517260  0.009156  0.177929
# 3 -0.175031  0.195024 -0.162889 -0.098613 -0.267194  0.277919  0.224994
# 4 -1.151966  0.268501 -1.011927 -0.390698  1.028616  0.704275  0.773432
#
#     map ldl   map hdl   map tch   map ltg   map glu      tc^2    tc ldl  \
# 0  1.065444 -1.612267  2.196796  0.906004  2.254727  0.137348  0.270067
# 1  0.271847 -0.943986  0.634200  1.524028  0.297917  0.110018  0.117515
# 2  0.167192  0.065633 -0.004802  0.048900 -0.079134  3.457632  3.248986
# 3  0.411353 -0.458342  0.382819  0.231758  0.627953  0.182148  0.333019
# 4  0.789633 -0.184048  0.693641  0.267810 -0.705081  0.849380  0.867172
#
#      tc hdl    tc tch    tc ltg    tc glu  tc female     ldl^2   ldl hdl  \
# 0 -0.408674  0.556840  0.229652  0.571524   0.370605  0.531030 -0.803573
# 1 -0.408071  0.274155  0.658814  0.128785  -0.331690  0.125523 -0.435877
# 2  1.275430 -0.093323  0.950252 -1.537777   1.859471  3.052930  1.198466
# 3 -0.371059  0.309918  0.187624  0.508371   0.426789  0.608853 -0.678401
# 4 -0.202121  0.761754  0.294108 -0.774317  -0.000000  0.885336 -0.206354
#
#     ldl tch   ldl ltg   ldl glu  ldl female     hdl^2   hdl tch   hdl ltg  \
# 0  1.094910  0.451563  1.123783    0.728718  1.215995 -1.656856 -0.683321
# 1  0.292836  0.703707  0.137561   -0.354292  1.513580 -1.016872 -2.443615
# 2 -0.087692  0.892911 -1.444982    1.747264  0.470473 -0.034424  0.350523
# 3  0.566618  0.343030  0.929446    0.780290  0.755894 -0.631343 -0.382214
# 4  0.777710  0.300268 -0.790536   -0.000000  0.048097 -0.181269 -0.069987
#
#     hdl glu     tch^2   tch ltg   tch glu  tch female     ltg^2   ltg glu  \
# 0 -1.700548  2.257552  0.931061  2.317084    1.502515  0.383988  0.955613
# 1 -0.477678  0.683168  1.641700  0.320919   -0.826539  3.945119  0.771192
# 2 -0.567246  0.002519 -0.025648  0.041505   -0.050188  0.261155 -0.422623
# 3 -1.035616  0.527314  0.319235  0.864973    0.726164  0.193264  0.523653
# 4  0.184259  0.683168  0.263766 -0.694435   -0.000000  0.101838 -0.268117
#
#       glu^2
# 0  2.378187
# 1  0.150752
# 2  0.683924
# 3  1.418849
# 4  0.705888

# %%
import seaborn as sns

sns.set(style="white")


# Compute the correlation matrix
corr = features_selected_train.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# Create correlation matrix
corr_matrix = features_selected_train.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
upper
# Out:
#             age       bmi       map        tc       ldl       hdl       tch  \
# age         NaN  0.167852  0.294671  0.226157  0.193177  0.054069  0.157053
# bmi         NaN       NaN  0.384811  0.247464  0.256477  0.381363  0.426283
# map         NaN       NaN       NaN  0.210655  0.161749  0.175649  0.239444
# tc          NaN       NaN       NaN       NaN  0.902931  0.071988  0.548544
# ldl         NaN       NaN       NaN       NaN       NaN  0.164936  0.665067
# hdl         NaN       NaN       NaN       NaN       NaN       NaN  0.718960
# tch         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ltg         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# glu         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# age^2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# age bmi     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# age map     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# age tc      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# age ldl     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# age hdl     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# age tch     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# age ltg     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# age glu     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# bmi^2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# bmi map     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# bmi tc      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# bmi ldl     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# bmi hdl     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# bmi tch     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# bmi ltg     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# bmi glu     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# map^2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# map tc      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# map ldl     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# map hdl     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# map tch     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# map ltg     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# map glu     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# tc^2        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# tc ldl      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# tc hdl      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# tc tch      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# tc ltg      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# tc glu      NaN       NaN       NaN       NaN       NaN       NaN       NaN
# tc female   NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ldl^2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ldl hdl     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ldl tch     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ldl ltg     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ldl glu     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ldl female  NaN       NaN       NaN       NaN       NaN       NaN       NaN
# hdl^2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# hdl tch     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# hdl ltg     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# hdl glu     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# tch^2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# tch ltg     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# tch glu     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# tch female  NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ltg^2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ltg glu     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# glu^2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#                  ltg       glu     age^2   age bmi   age map    age tc  \
# age         0.229117  0.271211  0.148133  0.158077  0.146296  0.127589
# bmi         0.464156  0.413631  0.138727  0.203116  0.066735  0.226232
# map         0.373188  0.373482  0.120253  0.062507  0.028776  0.105595
# tc          0.520972  0.288983  0.114122  0.230579  0.114905  0.061482
# ldl         0.332134  0.261663  0.098720  0.237720  0.161674  0.089313
# hdl         0.397006  0.289281  0.012206  0.017253  0.061670  0.131677
# tch         0.615445  0.418004  0.105918  0.167976  0.119822  0.179762
# ltg              NaN  0.462754  0.099279  0.124336  0.023907  0.122150
# glu              NaN       NaN  0.130802  0.102082  0.042991  0.167049
# age^2            NaN       NaN       NaN  0.307205  0.336647  0.320509
# age bmi          NaN       NaN       NaN       NaN  0.420610  0.375436
# age map          NaN       NaN       NaN       NaN       NaN  0.285014
# age tc           NaN       NaN       NaN       NaN       NaN       NaN
# age ldl          NaN       NaN       NaN       NaN       NaN       NaN
# age hdl          NaN       NaN       NaN       NaN       NaN       NaN
# age tch          NaN       NaN       NaN       NaN       NaN       NaN
# age ltg          NaN       NaN       NaN       NaN       NaN       NaN
# age glu          NaN       NaN       NaN       NaN       NaN       NaN
# bmi^2            NaN       NaN       NaN       NaN       NaN       NaN
# bmi map          NaN       NaN       NaN       NaN       NaN       NaN
# bmi tc           NaN       NaN       NaN       NaN       NaN       NaN
# bmi ldl          NaN       NaN       NaN       NaN       NaN       NaN
# bmi hdl          NaN       NaN       NaN       NaN       NaN       NaN
# bmi tch          NaN       NaN       NaN       NaN       NaN       NaN
# bmi ltg          NaN       NaN       NaN       NaN       NaN       NaN
# bmi glu          NaN       NaN       NaN       NaN       NaN       NaN
# map^2            NaN       NaN       NaN       NaN       NaN       NaN
# map tc           NaN       NaN       NaN       NaN       NaN       NaN
# map ldl          NaN       NaN       NaN       NaN       NaN       NaN
# map hdl          NaN       NaN       NaN       NaN       NaN       NaN
# map tch          NaN       NaN       NaN       NaN       NaN       NaN
# map ltg          NaN       NaN       NaN       NaN       NaN       NaN
# map glu          NaN       NaN       NaN       NaN       NaN       NaN
# tc^2             NaN       NaN       NaN       NaN       NaN       NaN
# tc ldl           NaN       NaN       NaN       NaN       NaN       NaN
# tc hdl           NaN       NaN       NaN       NaN       NaN       NaN
# tc tch           NaN       NaN       NaN       NaN       NaN       NaN
# tc ltg           NaN       NaN       NaN       NaN       NaN       NaN
# tc glu           NaN       NaN       NaN       NaN       NaN       NaN
# tc female        NaN       NaN       NaN       NaN       NaN       NaN
# ldl^2            NaN       NaN       NaN       NaN       NaN       NaN
# ldl hdl          NaN       NaN       NaN       NaN       NaN       NaN
# ldl tch          NaN       NaN       NaN       NaN       NaN       NaN
# ldl ltg          NaN       NaN       NaN       NaN       NaN       NaN
# ldl glu          NaN       NaN       NaN       NaN       NaN       NaN
# ldl female       NaN       NaN       NaN       NaN       NaN       NaN
# hdl^2            NaN       NaN       NaN       NaN       NaN       NaN
# hdl tch          NaN       NaN       NaN       NaN       NaN       NaN
# hdl ltg          NaN       NaN       NaN       NaN       NaN       NaN
# hdl glu          NaN       NaN       NaN       NaN       NaN       NaN
# tch^2            NaN       NaN       NaN       NaN       NaN       NaN
# tch ltg          NaN       NaN       NaN       NaN       NaN       NaN
# tch glu          NaN       NaN       NaN       NaN       NaN       NaN
# tch female       NaN       NaN       NaN       NaN       NaN       NaN
# ltg^2            NaN       NaN       NaN       NaN       NaN       NaN
# ltg glu          NaN       NaN       NaN       NaN       NaN       NaN
# glu^2            NaN       NaN       NaN       NaN       NaN       NaN
#
#              age ldl   age hdl   age tch   age ltg   age glu     bmi^2  \
# age         0.112754  0.015086  0.126712  0.113585  0.156760  0.140730
# bmi         0.238277  0.018713  0.176354  0.124840  0.107365  0.429389
# map         0.151785  0.062651  0.117827  0.022483  0.042351  0.042054
# tc          0.091243  0.145566  0.192354  0.125002  0.179070  0.059898
# ldl         0.056642  0.095685  0.164926  0.206006  0.180219  0.069362
# hdl         0.088425  0.122658  0.012045  0.077447  0.048380  0.092868
# tch         0.157459  0.012444  0.118075  0.170897  0.057286  0.071222
# ltg         0.205655  0.083663  0.178696  0.021799  0.050572  0.079785
# glu         0.171753  0.049893  0.057184  0.048279  0.011371  0.128051
# age^2       0.327476  0.162212  0.350080  0.307470  0.416399  0.004092
# age bmi     0.383797  0.313074  0.458793  0.480006  0.387721  0.110660
# age map     0.216072  0.118649  0.240840  0.395679  0.368676  0.084312
# age tc      0.911732  0.064257  0.577931  0.584828  0.244013  0.015131
# age ldl          NaN  0.173408  0.698785  0.405377  0.250638  0.011499
# age hdl          NaN       NaN  0.706929  0.343957  0.315570  0.059950
# age tch          NaN       NaN       NaN  0.629033  0.447060  0.049668
# age ltg          NaN       NaN       NaN       NaN  0.395221  0.004455
# age glu          NaN       NaN       NaN       NaN       NaN  0.033372
# bmi^2            NaN       NaN       NaN       NaN       NaN       NaN
# bmi map          NaN       NaN       NaN       NaN       NaN       NaN
# bmi tc           NaN       NaN       NaN       NaN       NaN       NaN
# bmi ldl          NaN       NaN       NaN       NaN       NaN       NaN
# bmi hdl          NaN       NaN       NaN       NaN       NaN       NaN
# bmi tch          NaN       NaN       NaN       NaN       NaN       NaN
# bmi ltg          NaN       NaN       NaN       NaN       NaN       NaN
# bmi glu          NaN       NaN       NaN       NaN       NaN       NaN
# map^2            NaN       NaN       NaN       NaN       NaN       NaN
# map tc           NaN       NaN       NaN       NaN       NaN       NaN
# map ldl          NaN       NaN       NaN       NaN       NaN       NaN
# map hdl          NaN       NaN       NaN       NaN       NaN       NaN
# map tch          NaN       NaN       NaN       NaN       NaN       NaN
# map ltg          NaN       NaN       NaN       NaN       NaN       NaN
# map glu          NaN       NaN       NaN       NaN       NaN       NaN
# tc^2             NaN       NaN       NaN       NaN       NaN       NaN
# tc ldl           NaN       NaN       NaN       NaN       NaN       NaN
# tc hdl           NaN       NaN       NaN       NaN       NaN       NaN
# tc tch           NaN       NaN       NaN       NaN       NaN       NaN
# tc ltg           NaN       NaN       NaN       NaN       NaN       NaN
# tc glu           NaN       NaN       NaN       NaN       NaN       NaN
# tc female        NaN       NaN       NaN       NaN       NaN       NaN
# ldl^2            NaN       NaN       NaN       NaN       NaN       NaN
# ldl hdl          NaN       NaN       NaN       NaN       NaN       NaN
# ldl tch          NaN       NaN       NaN       NaN       NaN       NaN
# ldl ltg          NaN       NaN       NaN       NaN       NaN       NaN
# ldl glu          NaN       NaN       NaN       NaN       NaN       NaN
# ldl female       NaN       NaN       NaN       NaN       NaN       NaN
# hdl^2            NaN       NaN       NaN       NaN       NaN       NaN
# hdl tch          NaN       NaN       NaN       NaN       NaN       NaN
# hdl ltg          NaN       NaN       NaN       NaN       NaN       NaN
# hdl glu          NaN       NaN       NaN       NaN       NaN       NaN
# tch^2            NaN       NaN       NaN       NaN       NaN       NaN
# tch ltg          NaN       NaN       NaN       NaN       NaN       NaN
# tch glu          NaN       NaN       NaN       NaN       NaN       NaN
# tch female       NaN       NaN       NaN       NaN       NaN       NaN
# ltg^2            NaN       NaN       NaN       NaN       NaN       NaN
# ltg glu          NaN       NaN       NaN       NaN       NaN       NaN
# glu^2            NaN       NaN       NaN       NaN       NaN       NaN
#
#              bmi map    bmi tc   bmi ldl   bmi hdl   bmi tch   bmi ltg  \
# age         0.059027  0.246144  0.255000  0.018319  0.169021  0.129445
# bmi         0.057317  0.092287  0.107387  0.142323  0.103433  0.119886
# map         0.145892  0.097003  0.149096  0.037348  0.080429  0.022717
# tc          0.085810  0.011615  0.026257  0.051258  0.041611  0.020668
# ldl         0.131254  0.026130  0.032495  0.084510  0.011439  0.095747
# hdl         0.033215  0.051532  0.085374  0.290643  0.035348  0.009914
# tch         0.075482  0.044145  0.012194  0.037301  0.129805  0.037528
# ltg         0.020606  0.021193  0.098653  0.010111  0.036271  0.062517
# glu         0.046112  0.006730  0.049641  0.085187  0.106477  0.116386
# age^2       0.042439  0.157878  0.144882  0.085598  0.024947  0.039266
# age bmi     0.329696  0.177671  0.182355  0.073915  0.156635  0.154228
# age map     0.085469  0.033028  0.052558  0.090924  0.073776  0.076772
# age tc      0.013490  0.127519  0.100764  0.078788  0.032305  0.050081
# age ldl     0.044638  0.113598  0.131805  0.065129  0.031271  0.001778
# age hdl     0.178010  0.001332  0.000082  0.075960  0.034598  0.071534
# age tch     0.134130  0.102587  0.083340  0.006642  0.068154  0.088102
# age ltg     0.112592  0.105433  0.032180  0.000326  0.055855  0.182227
# age glu     0.105635  0.068160  0.013400  0.015818  0.054450  0.122383
# bmi^2       0.332165  0.152438  0.193616  0.465351  0.495801  0.462684
# bmi map          NaN  0.135972  0.085080  0.175121  0.197734  0.347870
# bmi tc           NaN       NaN  0.895687  0.079244  0.539988  0.510968
# bmi ldl          NaN       NaN       NaN  0.144158  0.632113  0.298861
# bmi hdl          NaN       NaN       NaN       NaN  0.706689  0.405804
# bmi tch          NaN       NaN       NaN       NaN       NaN  0.636106
# bmi ltg          NaN       NaN       NaN       NaN       NaN       NaN
# bmi glu          NaN       NaN       NaN       NaN       NaN       NaN
# map^2            NaN       NaN       NaN       NaN       NaN       NaN
# map tc           NaN       NaN       NaN       NaN       NaN       NaN
# map ldl          NaN       NaN       NaN       NaN       NaN       NaN
# map hdl          NaN       NaN       NaN       NaN       NaN       NaN
# map tch          NaN       NaN       NaN       NaN       NaN       NaN
# map ltg          NaN       NaN       NaN       NaN       NaN       NaN
# map glu          NaN       NaN       NaN       NaN       NaN       NaN
# tc^2             NaN       NaN       NaN       NaN       NaN       NaN
# tc ldl           NaN       NaN       NaN       NaN       NaN       NaN
# tc hdl           NaN       NaN       NaN       NaN       NaN       NaN
# tc tch           NaN       NaN       NaN       NaN       NaN       NaN
# tc ltg           NaN       NaN       NaN       NaN       NaN       NaN
# tc glu           NaN       NaN       NaN       NaN       NaN       NaN
# tc female        NaN       NaN       NaN       NaN       NaN       NaN
# ldl^2            NaN       NaN       NaN       NaN       NaN       NaN
# ldl hdl          NaN       NaN       NaN       NaN       NaN       NaN
# ldl tch          NaN       NaN       NaN       NaN       NaN       NaN
# ldl ltg          NaN       NaN       NaN       NaN       NaN       NaN
# ldl glu          NaN       NaN       NaN       NaN       NaN       NaN
# ldl female       NaN       NaN       NaN       NaN       NaN       NaN
# hdl^2            NaN       NaN       NaN       NaN       NaN       NaN
# hdl tch          NaN       NaN       NaN       NaN       NaN       NaN
# hdl ltg          NaN       NaN       NaN       NaN       NaN       NaN
# hdl glu          NaN       NaN       NaN       NaN       NaN       NaN
# tch^2            NaN       NaN       NaN       NaN       NaN       NaN
# tch ltg          NaN       NaN       NaN       NaN       NaN       NaN
# tch glu          NaN       NaN       NaN       NaN       NaN       NaN
# tch female       NaN       NaN       NaN       NaN       NaN       NaN
# ltg^2            NaN       NaN       NaN       NaN       NaN       NaN
# ltg glu          NaN       NaN       NaN       NaN       NaN       NaN
# glu^2            NaN       NaN       NaN       NaN       NaN       NaN
#
#              bmi glu     map^2    map tc   map ldl   map hdl   map tch  \
# age         0.100632  0.021696  0.112208  0.157724  0.054640  0.114674
# bmi         0.182191  0.124365  0.094740  0.144769  0.033272  0.081673
# map         0.048137  0.255568  0.037992  0.017491  0.050432  0.015217
# tc          0.006215  0.029334  0.017809  0.029892  0.010875  0.002139
# ldl         0.045619  0.013518  0.029922  0.004134  0.040550  0.041864
# hdl         0.079087  0.042917  0.011986  0.044649  0.087694  0.012616
# tch         0.104316  0.011989  0.002182  0.042675  0.011680  0.047480
# ltg         0.110205  0.076849  0.019322  0.116938  0.019575  0.008435
# glu         0.119995  0.138060  0.102467  0.135924  0.013623  0.049903
# age^2       0.006564  0.039580  0.114274  0.086625  0.050458  0.015635
# age bmi     0.248451  0.023435  0.070239  0.099352  0.156011  0.159378
# age map     0.093095  0.144099  0.196977  0.148801  0.003027  0.066780
# age tc      0.032590  0.007309  0.189634  0.144048  0.058476  0.040520
# age ldl     0.001289  0.012034  0.142913  0.180556  0.010445  0.051260
# age hdl     0.073446  0.004678  0.038501  0.041526  0.317445  0.198756
# age tch     0.106828  0.022978  0.067812  0.078035  0.163247  0.171698
# age ltg     0.142104  0.045142  0.142432  0.037441  0.069120  0.139757
# age glu     0.216502  0.003565  0.060060  0.037951  0.045223  0.097134
# bmi^2       0.466316  0.139810  0.012214  0.014105  0.095108  0.092761
# bmi map     0.391110  0.469055  0.181841  0.206520  0.381196  0.387056
# bmi tc      0.298870  0.012565  0.305629  0.249728  0.060735  0.127179
# bmi ldl     0.246772  0.009886  0.235187  0.250440  0.022537  0.107637
# bmi hdl     0.336452  0.090644  0.108302  0.043368  0.272617  0.152445
# bmi tch     0.459771  0.048296  0.089570  0.094846  0.149732  0.218641
# bmi ltg     0.543539  0.092982  0.160571  0.084536  0.138641  0.201986
# bmi glu          NaN  0.168793  0.045285  0.028235  0.142988  0.151865
# map^2            NaN       NaN  0.222681  0.162012  0.078684  0.159768
# map tc           NaN       NaN       NaN  0.886488  0.086827  0.534141
# map ldl          NaN       NaN       NaN       NaN  0.197571  0.666117
# map hdl          NaN       NaN       NaN       NaN       NaN  0.709941
# map tch          NaN       NaN       NaN       NaN       NaN       NaN
# map ltg          NaN       NaN       NaN       NaN       NaN       NaN
# map glu          NaN       NaN       NaN       NaN       NaN       NaN
# tc^2             NaN       NaN       NaN       NaN       NaN       NaN
# tc ldl           NaN       NaN       NaN       NaN       NaN       NaN
# tc hdl           NaN       NaN       NaN       NaN       NaN       NaN
# tc tch           NaN       NaN       NaN       NaN       NaN       NaN
# tc ltg           NaN       NaN       NaN       NaN       NaN       NaN
# tc glu           NaN       NaN       NaN       NaN       NaN       NaN
# tc female        NaN       NaN       NaN       NaN       NaN       NaN
# ldl^2            NaN       NaN       NaN       NaN       NaN       NaN
# ldl hdl          NaN       NaN       NaN       NaN       NaN       NaN
# ldl tch          NaN       NaN       NaN       NaN       NaN       NaN
# ldl ltg          NaN       NaN       NaN       NaN       NaN       NaN
# ldl glu          NaN       NaN       NaN       NaN       NaN       NaN
# ldl female       NaN       NaN       NaN       NaN       NaN       NaN
# hdl^2            NaN       NaN       NaN       NaN       NaN       NaN
# hdl tch          NaN       NaN       NaN       NaN       NaN       NaN
# hdl ltg          NaN       NaN       NaN       NaN       NaN       NaN
# hdl glu          NaN       NaN       NaN       NaN       NaN       NaN
# tch^2            NaN       NaN       NaN       NaN       NaN       NaN
# tch ltg          NaN       NaN       NaN       NaN       NaN       NaN
# tch glu          NaN       NaN       NaN       NaN       NaN       NaN
# tch female       NaN       NaN       NaN       NaN       NaN       NaN
# ltg^2            NaN       NaN       NaN       NaN       NaN       NaN
# ltg glu          NaN       NaN       NaN       NaN       NaN       NaN
# glu^2            NaN       NaN       NaN       NaN       NaN       NaN
#
#              map ltg   map glu      tc^2    tc ldl    tc hdl    tc tch  \
# age         0.024078  0.037836  0.042535  0.060709  0.144792  0.148157
# bmi         0.023463  0.045882  0.007385  0.016324  0.052081  0.033440
# map         0.102652  0.161151  0.011595  0.019140  0.012403  0.001693
# tc          0.019927  0.092347  0.289382  0.274457  0.059426  0.203325
# ldl         0.120722  0.122620  0.279345  0.315836  0.108384  0.239115
# hdl         0.022251  0.013532  0.037389  0.066999  0.205448  0.187663
# tch         0.008876  0.045891  0.170675  0.197205  0.250374  0.309738
# ltg         0.050441  0.006348  0.134486  0.082183  0.034162  0.106627
# glu         0.007264  0.047178  0.022662  0.041680  0.106243  0.094883
# age^2       0.053498  0.023322  0.041108  0.028605  0.024327  0.026049
# age bmi     0.155740  0.139960  0.005020  0.000081  0.026836  0.030042
# age map     0.203922  0.169462  0.048628  0.066641  0.000834  0.059952
# age tc      0.104581  0.024739  0.186019  0.161222  0.009390  0.082852
# age ldl     0.000004  0.005405  0.175306  0.172435  0.022535  0.090250
# age hdl     0.108796  0.074913  0.059468  0.031301  0.121383  0.018312
# age tch     0.149459  0.095500  0.050386  0.052312  0.071072  0.051612
# age ltg     0.334295  0.118892  0.078147  0.038244  0.018245  0.046013
# age glu     0.124439  0.309277  0.085973  0.068056  0.096063  0.014049
# bmi^2       0.115454  0.130918  0.038540  0.035023  0.074841  0.027949
# bmi map     0.445325  0.433514  0.041932  0.056436  0.012829  0.029464
# bmi tc      0.176170  0.038772  0.395382  0.437680  0.416479  0.537546
# bmi ldl     0.065591  0.002040  0.423056  0.452361  0.367580  0.532359
# bmi hdl     0.089795  0.081833  0.033417  0.037668  0.035556  0.002245
# bmi tch     0.152422  0.084406  0.222501  0.244346  0.263318  0.368685
# bmi ltg     0.356906  0.174128  0.075884  0.103286  0.226890  0.205614
# bmi glu     0.209257  0.445216  0.055047  0.065286  0.156876  0.154734
# map^2       0.352064  0.395710  0.031009  0.038485  0.020284  0.005009
# map tc      0.533865  0.240533  0.124450  0.129492  0.232106  0.191218
# map ldl     0.332297  0.203022  0.152231  0.168997  0.194536  0.197162
# map hdl     0.347144  0.232058  0.007271  0.000555  0.023768  0.043467
# map tch     0.600553  0.352128  0.069483  0.070734  0.190620  0.180708
# map ltg          NaN  0.453794  0.014153  0.038869  0.179731  0.083444
# map glu          NaN       NaN  0.075194  0.071231  0.102325  0.018174
# tc^2             NaN       NaN       NaN  0.952465  0.000165  0.704866
# tc ldl           NaN       NaN       NaN       NaN  0.178504  0.796865
# tc hdl           NaN       NaN       NaN       NaN       NaN  0.636065
# tc tch           NaN       NaN       NaN       NaN       NaN       NaN
# tc ltg           NaN       NaN       NaN       NaN       NaN       NaN
# tc glu           NaN       NaN       NaN       NaN       NaN       NaN
# tc female        NaN       NaN       NaN       NaN       NaN       NaN
# ldl^2            NaN       NaN       NaN       NaN       NaN       NaN
# ldl hdl          NaN       NaN       NaN       NaN       NaN       NaN
# ldl tch          NaN       NaN       NaN       NaN       NaN       NaN
# ldl ltg          NaN       NaN       NaN       NaN       NaN       NaN
# ldl glu          NaN       NaN       NaN       NaN       NaN       NaN
# ldl female       NaN       NaN       NaN       NaN       NaN       NaN
# hdl^2            NaN       NaN       NaN       NaN       NaN       NaN
# hdl tch          NaN       NaN       NaN       NaN       NaN       NaN
# hdl ltg          NaN       NaN       NaN       NaN       NaN       NaN
# hdl glu          NaN       NaN       NaN       NaN       NaN       NaN
# tch^2            NaN       NaN       NaN       NaN       NaN       NaN
# tch ltg          NaN       NaN       NaN       NaN       NaN       NaN
# tch glu          NaN       NaN       NaN       NaN       NaN       NaN
# tch female       NaN       NaN       NaN       NaN       NaN       NaN
# ltg^2            NaN       NaN       NaN       NaN       NaN       NaN
# ltg glu          NaN       NaN       NaN       NaN       NaN       NaN
# glu^2            NaN       NaN       NaN       NaN       NaN       NaN
#
#               tc ltg    tc glu  tc female     ldl^2   ldl hdl   ldl tch  \
# age         0.124427  0.180085   0.075224  0.034860  0.093374  0.112630
# bmi         0.019842  0.006668   0.174947  0.018687  0.084240  0.008151
# map         0.018522  0.103953   0.135911  0.002449  0.045373  0.029376
# tc          0.198016  0.035312   0.716220  0.292143  0.106332  0.212008
# ldl         0.123161  0.066104   0.654070  0.320278  0.121522  0.284464
# hdl         0.031647  0.104160   0.031643  0.070826  0.133047  0.078651
# tch         0.131785  0.124107   0.404906  0.244752  0.116110  0.275369
# ltg         0.091631  0.020933   0.362386  0.109856  0.110045  0.008100
# glu         0.019779  0.045723   0.195699  0.079933  0.029047  0.068606
# age^2       0.100121  0.003522   0.053556  0.006173  0.001488  0.009625
# age bmi     0.066903  0.084329   0.169069  0.001029  0.015022  0.000770
# age map     0.030398  0.029508   0.046445  0.063419  0.004496  0.078825
# age tc      0.223982  0.093372   0.032961  0.124125  0.032711  0.046373
# age ldl     0.165991  0.101998   0.001603  0.135895  0.002097  0.076890
# age hdl     0.031225  0.055911   0.074666  0.013864  0.013364  0.023397
# age tch     0.106503  0.135684   0.060596  0.050377  0.022013  0.002845
# age ltg     0.237185  0.098719   0.037200  0.018154  0.069755  0.033265
# age glu     0.017046  0.219920   0.111222  0.048742  0.021579  0.016379
# bmi^2       0.030949  0.068347   0.014351  0.036660  0.042503  0.008762
# bmi map     0.040552  0.019436   0.031613  0.073837  0.041017  0.068113
# bmi tc      0.480120  0.487700   0.151132  0.405713  0.290420  0.451038
# bmi ldl     0.472301  0.459821   0.149584  0.426915  0.419879  0.522764
# bmi hdl     0.037368  0.004975   0.051723  0.015243  0.242560  0.084103
# bmi tch     0.279049  0.319395   0.125800  0.259687  0.317208  0.352413
# bmi ltg     0.218845  0.238190   0.059797  0.103470  0.080036  0.112080
# bmi glu     0.131188  0.321027   0.050792  0.073384  0.079828  0.101626
# map^2       0.019383  0.026040   0.056923  0.036519  0.051966  0.008225
# map tc      0.260362  0.222327   0.174868  0.114005  0.138721  0.135735
# map ldl     0.212433  0.201854   0.166413  0.137238  0.166488  0.187236
# map hdl     0.032092  0.021591   0.036266  0.000723  0.000453  0.005506
# map tch     0.181466  0.175718   0.150758  0.073084  0.094252  0.100087
# map ltg     0.242378  0.149666   0.074815  0.025248  0.048884  0.018634
# map glu     0.040337  0.233846   0.009597  0.070231  0.005279  0.039639
# tc^2        0.635046  0.350581   0.280337  0.862404  0.009398  0.634667
# tc ldl      0.495876  0.380255   0.326266  0.960428  0.160675  0.768932
# tc hdl      0.284475  0.333218   0.331213  0.301761  0.731377  0.567601
# tc tch      0.586580  0.501053   0.369751  0.828683  0.507023  0.913738
# tc ltg           NaN  0.398852   0.247633  0.387231  0.187991  0.404129
# tc glu           NaN       NaN   0.201926  0.373149  0.244611  0.426057
# tc female        NaN       NaN        NaN  0.371026  0.310736  0.366082
# ldl^2            NaN       NaN        NaN       NaN  0.315105  0.839705
# ldl hdl          NaN       NaN        NaN       NaN       NaN  0.679210
# ldl tch          NaN       NaN        NaN       NaN       NaN       NaN
# ldl ltg          NaN       NaN        NaN       NaN       NaN       NaN
# ldl glu          NaN       NaN        NaN       NaN       NaN       NaN
# ldl female       NaN       NaN        NaN       NaN       NaN       NaN
# hdl^2            NaN       NaN        NaN       NaN       NaN       NaN
# hdl tch          NaN       NaN        NaN       NaN       NaN       NaN
# hdl ltg          NaN       NaN        NaN       NaN       NaN       NaN
# hdl glu          NaN       NaN        NaN       NaN       NaN       NaN
# tch^2            NaN       NaN        NaN       NaN       NaN       NaN
# tch ltg          NaN       NaN        NaN       NaN       NaN       NaN
# tch glu          NaN       NaN        NaN       NaN       NaN       NaN
# tch female       NaN       NaN        NaN       NaN       NaN       NaN
# ltg^2            NaN       NaN        NaN       NaN       NaN       NaN
# ltg glu          NaN       NaN        NaN       NaN       NaN       NaN
# glu^2            NaN       NaN        NaN       NaN       NaN       NaN
#
#              ldl ltg   ldl glu  ldl female     hdl^2   hdl tch   hdl ltg  \
# age         0.206701  0.171860    0.077279  0.061927  0.009790  0.081348
# bmi         0.092652  0.046414    0.150700  0.149890  0.029977  0.010043
# map         0.113107  0.130888    0.109100  0.050766  0.010536  0.021824
# tc          0.124147  0.062682    0.655748  0.104280  0.198033  0.033395
# ldl         0.179408  0.129961    0.720558  0.068834  0.093609  0.109647
# hdl         0.104742  0.027525    0.097780  0.485506  0.173620  0.081334
# tch         0.011382  0.095972    0.484772  0.111417  0.253159  0.106492
# ltg         0.180351  0.096507    0.221717  0.042232  0.086166  0.096956
# glu         0.096937  0.007841    0.152854  0.034448  0.094953  0.080524
# age^2       0.095989  0.021000    0.056383  0.081246  0.078890  0.071515
# age bmi     0.033204  0.038195    0.157510  0.046287  0.058098  0.022031
# age map     0.028343  0.000721    0.080632  0.010484  0.021828  0.006373
# age tc      0.189569  0.091303    0.015762  0.070597  0.096278  0.094971
# age ldl     0.199846  0.151209    0.029904  0.109759  0.115714  0.111416
# age hdl     0.049574  0.055094    0.019727  0.128713  0.054392  0.106467
# age tch     0.059462  0.127025    0.043596  0.103229  0.058246  0.017990
# age ltg     0.105551  0.014468    0.144302  0.065517  0.075728  0.011326
# age glu     0.017404  0.140394    0.128233  0.061799  0.008693  0.058962
# bmi^2       0.034776  0.051670    0.011799  0.005128  0.054842  0.103937
# bmi map     0.022893  0.006662    0.062620  0.027626  0.039428  0.067686
# bmi tc      0.530305  0.444163    0.129631  0.182399  0.026739  0.075924
# bmi ldl     0.592689  0.510870    0.150610  0.010558  0.165896  0.052953
# bmi hdl     0.022912  0.047120    0.011478  0.584623  0.536610  0.387089
# bmi tch     0.325352  0.313807    0.076534  0.240666  0.454609  0.349259
# bmi ltg     0.182637  0.119520    0.014967  0.014831  0.143050  0.384041
# bmi glu     0.097508  0.244852    0.007910  0.011796  0.116182  0.212712
# map^2       0.015357  0.001415    0.018998  0.055999  0.029319  0.002144
# map tc      0.229698  0.182642    0.149442  0.117005  0.000452  0.046177
# map ldl     0.302677  0.227005    0.190876  0.077145  0.007695  0.044191
# map hdl     0.044062  0.020202    0.014874  0.135858  0.149193  0.306805
# map tch     0.152574  0.134247    0.123748  0.038704  0.175062  0.299862
# map ltg     0.060698  0.023582    0.022287  0.001537  0.092858  0.240796
# map glu     0.004839  0.125356    0.073622  0.065587  0.030406  0.094402
# tc^2        0.605386  0.366488    0.280603  0.058594  0.026706  0.129050
# tc ldl      0.573801  0.418575    0.358354  0.107557  0.012155  0.070929
# tc hdl      0.315169  0.309974    0.328826  0.324361  0.200565  0.330124
# tc tch      0.596243  0.495998    0.382683  0.175220  0.185357  0.155743
# tc ltg      0.775843  0.330415    0.178272  0.148612  0.019087  0.025713
# tc glu      0.395170  0.889560    0.203064  0.096108  0.082249  0.099722
# tc female   0.222560  0.214332    0.913967  0.002370  0.204301  0.100713
# ldl^2       0.436369  0.406061    0.410056  0.034337  0.143345  0.000688
# ldl hdl     0.374102  0.334287    0.371812  0.275074  0.586798  0.190057
# ldl tch     0.562636  0.505337    0.448677  0.035785  0.352742  0.060338
# ldl ltg          NaN  0.468605    0.245961  0.056423  0.090782  0.002200
# ldl glu          NaN       NaN    0.276857  0.030779  0.122749  0.047261
# ldl female       NaN       NaN         NaN  0.017608  0.208627  0.010127
# hdl^2            NaN       NaN         NaN       NaN  0.769444  0.328581
# hdl tch          NaN       NaN         NaN       NaN       NaN  0.532655
# hdl ltg          NaN       NaN         NaN       NaN       NaN       NaN
# hdl glu          NaN       NaN         NaN       NaN       NaN       NaN
# tch^2            NaN       NaN         NaN       NaN       NaN       NaN
# tch ltg          NaN       NaN         NaN       NaN       NaN       NaN
# tch glu          NaN       NaN         NaN       NaN       NaN       NaN
# tch female       NaN       NaN         NaN       NaN       NaN       NaN
# ltg^2            NaN       NaN         NaN       NaN       NaN       NaN
# ltg glu          NaN       NaN         NaN       NaN       NaN       NaN
# glu^2            NaN       NaN         NaN       NaN       NaN       NaN
#
#              hdl glu     tch^2   tch ltg   tch glu  tch female     ltg^2  \
# age         0.048057  0.068629  0.159287  0.048744    0.071962  0.015986
# bmi         0.083815  0.078720  0.033734  0.094699    0.262777  0.044215
# map         0.015046  0.028356  0.007725  0.043707    0.167494  0.034541
# tc          0.102881  0.233734  0.123400  0.105005    0.406218  0.067507
# ldl         0.028671  0.234367  0.010573  0.085632    0.485099  0.131814
# hdl         0.065721  0.181035  0.094498  0.099581    0.465827  0.067692
# tch         0.116251  0.490391  0.281391  0.242184    0.748722  0.129825
# ltg         0.079769  0.183481  0.165006  0.088950    0.405179  0.196472
# glu         0.105382  0.165140  0.093019  0.142165    0.242268  0.043959
# age^2       0.003712  0.047989  0.003682  0.016630    0.047077  0.015203
# age bmi     0.043796  0.023563  0.046349  0.087615    0.084329  0.082072
# age map     0.007831  0.066898  0.006936  0.029492    0.097174  0.075355
# age tc      0.002216  0.049276  0.039361  0.063177    0.103297  0.091900
# age ldl     0.008365  0.053155  0.011239  0.071853    0.069906  0.011303
# age hdl     0.174403  0.003224  0.046656  0.161622    0.055237  0.038656
# age tch     0.157036  0.005050  0.072344  0.206370    0.007045  0.092796
# age ltg     0.100138  0.037835  0.128203  0.138076    0.122581  0.241827
# age glu     0.133897  0.006129  0.079680  0.197022    0.005926  0.089012
# bmi^2       0.135350  0.063986  0.116989  0.134240    0.077947  0.061600
# bmi map     0.112291  0.043979  0.054275  0.074025    0.043929  0.071311
# bmi tc      0.048962  0.286088  0.348458  0.305974    0.084354  0.160778
# bmi ldl     0.078900  0.337838  0.305508  0.302747    0.064020  0.054941
# bmi hdl     0.368133  0.293468  0.260557  0.265242    0.084917  0.115976
# bmi tch     0.332211  0.520474  0.494356  0.476523    0.219056  0.208615
# bmi ltg     0.255821  0.202485  0.414367  0.315816    0.075098  0.383306
# bmi glu     0.423721  0.173579  0.255629  0.449292    0.120051  0.187398
# map^2       0.027306  0.002769  0.006716  0.022290    0.030026  0.008785
# map tc      0.012174  0.087573  0.168492  0.133716    0.110392  0.160402
# map ldl     0.022247  0.085208  0.124530  0.117379    0.112484  0.013343
# map hdl     0.199945  0.113832  0.234540  0.136697    0.118799  0.128327
# map tch     0.176909  0.226617  0.360318  0.238412    0.258718  0.210022
# map ltg     0.153308  0.095802  0.290955  0.174641    0.098729  0.444906
# map glu     0.241877  0.010719  0.093206  0.242392    0.015940  0.128030
# tc^2        0.017673  0.337476  0.247012  0.194751    0.167067  0.128175
# tc ldl      0.000171  0.417555  0.218528  0.222315    0.216017  0.012049
# tc hdl      0.169876  0.490652  0.454835  0.322701    0.293121  0.206997
# tc tch      0.119367  0.685370  0.518350  0.410107    0.343106  0.209924
# tc ltg      0.054947  0.303436  0.547642  0.273859    0.123941  0.543079
# tc glu      0.088434  0.326398  0.343465  0.605959    0.157804  0.188130
# tc female   0.096927  0.319934  0.212433  0.182946    0.562749  0.083807
# ldl^2       0.040820  0.517723  0.216882  0.250283    0.287481  0.034503
# ldl hdl     0.179836  0.579151  0.243583  0.251231    0.293161  0.027961
# ldl tch     0.104162  0.722770  0.298765  0.339705    0.371596  0.016323
# ldl ltg     0.055418  0.322227  0.414744  0.247552    0.089176  0.047761
# ldl glu     0.234585  0.334256  0.236423  0.645208    0.149049  0.011182
# ldl female  0.050826  0.348231  0.096963  0.149349    0.658195  0.066598
# hdl^2       0.211393  0.293909  0.130467  0.080768    0.083356  0.015371
# hdl tch     0.338297  0.766004  0.481748  0.346368    0.446235  0.165103
# hdl ltg     0.376856  0.418135  0.738118  0.338892    0.187972  0.447983
# hdl glu          NaN  0.296483  0.338990  0.775463    0.189142  0.169629
# tch^2            NaN       NaN  0.646521  0.515840    0.599418  0.227743
# tch ltg          NaN       NaN       NaN  0.512031    0.327824  0.630394
# tch glu          NaN       NaN       NaN       NaN    0.293934  0.243700
# tch female       NaN       NaN       NaN       NaN         NaN  0.085728
# ltg^2            NaN       NaN       NaN       NaN         NaN       NaN
# ltg glu          NaN       NaN       NaN       NaN         NaN       NaN
# glu^2            NaN       NaN       NaN       NaN         NaN       NaN
#
#              ltg glu     glu^2
# age         0.044775  0.007112
# bmi         0.104099  0.080067
# map         0.006291  0.033027
# tc          0.018428  0.028435
# ldl         0.089599  0.005142
# hdl         0.071099  0.066351
# tch         0.092555  0.104494
# ltg         0.055593  0.101413
# glu         0.143564  0.206294
# age^2       0.028763  0.024752
# age bmi     0.149960  0.099927
# age map     0.073679  0.080979
# age tc      0.049028  0.030104
# age ldl     0.014677  0.005394
# age hdl     0.139009  0.104724
# age tch     0.173305  0.113723
# age ltg     0.265314  0.133367
# age glu     0.301484  0.337887
# bmi^2       0.163145  0.082866
# bmi map     0.152283  0.152334
# bmi tc      0.234947  0.124377
# bmi ldl     0.117157  0.067827
# bmi hdl     0.189907  0.100536
# bmi tch     0.314500  0.165674
# bmi ltg     0.447306  0.218671
# bmi glu     0.549010  0.551350
# map^2       0.088929  0.134042
# map tc      0.138042  0.089361
# map ldl     0.043809  0.046301
# map hdl     0.144224  0.110319
# map tch     0.216625  0.136501
# map ltg     0.390767  0.240534
# map glu     0.476726  0.547720
# tc^2        0.036792  0.019139
# tc ldl      0.026016  0.003089
# tc hdl      0.241818  0.169643
# tc tch      0.202796  0.107968
# tc ltg      0.270376  0.087537
# tc glu      0.520967  0.452943
# tc female   0.055941  0.079459
# ldl^2       0.045739  0.017040
# ldl hdl     0.071796  0.092364
# ldl tch     0.068046  0.071159
# ldl ltg     0.089316  0.042902
# ldl glu     0.261921  0.350787
# ldl female  0.044485  0.014297
# hdl^2       0.006907  0.007323
# hdl tch     0.149896  0.122471
# hdl ltg     0.322511  0.172963
# hdl glu     0.504196  0.479789
# tch^2       0.228058  0.162629
# tch ltg     0.440934  0.201009
# tch glu     0.631543  0.592624
# tch female  0.122485  0.102546
# ltg^2       0.483490  0.169552
# ltg glu          NaN  0.679458
# glu^2            NaN       NaN

# %%
to_drop
# Out:
# ['tc ldl', 'ldl^2']

# %%
features_selected_train.drop(columns=to_drop, inplace=True)
# Out:
# /Users/swilson5/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression, mutual_info_regression

# %%
def information_selector(X, y, scoring, k=5):
    selector = SelectKBest(score_func=scoring, k=k)
    selector.fit(X, y)
    return X[X.columns[selector.get_support(indices=True)]]

# %%
test = SelectKBest(score_func=mutual_info_regression, k=30)
fit = test.fit(features_selected_train, y_train)
# Out:
# /Users/swilson5/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)

# %%
features_selected_train[features_selected_train.columns[fit.get_support(indices=True)]].head()
# Out:
#         bmi       map        tc       hdl       tch       ltg       glu  \
# 0  1.826023  1.462079  0.370605 -1.102722  1.502515  0.619668  1.542137
# 1 -0.424891 -0.767296 -0.331690  1.230277 -0.826539 -1.986232 -0.388269
# 2 -0.625468  0.095688  1.859471  0.685910 -0.050188  0.511034 -0.826997
# 3 -0.224315  0.527180  0.426789 -0.869422  0.726164  0.439618  1.191154
# 4  1.224293 -0.839211 -0.921618  0.219311 -0.826539 -0.319121  0.840171
#
#       age^2    age tc   age hdl     bmi^2   bmi ldl   bmi hdl   bmi tch  \
# 0  1.870196  0.506821 -1.508028  3.334360  1.330656 -2.013595  2.743627
# 1  0.280319 -0.175614  0.651371  0.180533  0.150536 -0.522734  0.351190
# 2  0.574600  1.409523  0.519936  0.391210 -1.092857 -0.429015  0.031391
# 3  1.315032 -0.489419  0.997008  0.050317 -0.175031  0.195024 -0.162889
# 4  0.212549  0.424894 -0.101109  1.498894 -1.151966  0.268501 -1.011927
#
#     bmi ltg   bmi glu   map hdl   map tch   map ltg   map glu      tc^2  \
# 0  1.131528  2.815978 -1.612267  2.196796  0.906004  2.254727  0.137348
# 1  0.843933  0.164972 -0.943986  0.634200  1.524028  0.297917  0.110018
# 2 -0.319635  0.517260  0.065633 -0.004802  0.048900 -0.079134  3.457632
# 3 -0.098613 -0.267194 -0.458342  0.382819  0.231758  0.627953  0.182148
# 4 -0.390698  1.028616 -0.184048  0.693641  0.267810 -0.705081  0.849380
#
#      tc tch    tc glu  tc female   ldl tch   hdl glu     tch^2   tch glu  \
# 0  0.556840  0.571524   0.370605  1.094910 -1.700548  2.257552  2.317084
# 1  0.274155  0.128785  -0.331690  0.292836 -0.477678  0.683168  0.320919
# 2 -0.093323 -1.537777   1.859471 -0.087692 -0.567246  0.002519  0.041505
# 3  0.309918  0.508371   0.426789  0.566618 -1.035616  0.527314  0.864973
# 4  0.761754 -0.774317  -0.000000  0.777710  0.184259  0.683168 -0.694435
#
#    tch female   ltg glu
# 0    1.502515  0.955613
# 1   -0.826539  0.771192
# 2   -0.050188 -0.422623
# 3    0.726164  0.523653
# 4   -0.000000 -0.268117

# %%
features_selected_train = information_selector(features_selected_train, y_train, mutual_info_regression, k=30)
# Out:
# /Users/swilson5/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)

# %%
# fit a model
lm = linear_model.LinearRegression()
model = lm.fit(features_selected_train, y_train)

# %%
features_selected_test = features_64_test[features_selected_train.columns]
y_pred = lm.predict(features_selected_test)

print(metrics.mean_absolute_error(y_test, y_pred))
print(metrics.mean_squared_error(y_test, y_pred))
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 43.58497516669367
# 3003.533845866089
# 54.804505707707

# %% [markdown]
# # Wrapper Methods
#
# Wrapper methods consider the selection of a set of features as a search problem, where different combinations are prepared, evaluated and compared to other combinations. A predictive model us used to evaluate a combination of features and assign a score based on model accuracy.
#
# The search process may be methodical such as a best-first search, it may stochastic such as a random hill-climbing algorithm, or it may use heuristics, like forward and backward passes to add and remove features.
#
# An example if a wrapper method is the recursive feature elimination algorithm.

# %% [markdown]
# ![alt text](Wrapper_1.webp)

# %%
from sklearn.feature_selection import RFE

# %%
rfe = RFE(lm, n_features_to_select=10)
rfe.fit(features_selected_train,y_train)
# Out:
# RFE(estimator=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False),
#   n_features_to_select=10, step=1, verbose=0)

# %%
def ranking(ranks, names, order=1):

    ranks = map(lambda x: round(x,2), ranks)
    return list(sorted(zip(ranks, names),reverse=True))

# %%
rankings = ranking(np.abs(lm.coef_), features_selected_train.columns)

# %%
rankings[:15]
# Out:
# (29.23, 'ltg')

# %%
[item[1] for item in rankings[0:15]]
# Out:
# ['tc tch',
#  'ltg',
#  'tch glu',
#  'bmi',
#  'ldl tch',
#  'map',
#  'hdl glu',
#  'tch female',
#  'tc',
#  'tc female',
#  'hdl',
#  'bmi ldl',
#  'map ltg',
#  'age^2',
#  'bmi tch']

# %%
final_columns = [item[1] for item in rankings[0:15]]

# %%
lm = linear_model.LinearRegression()
model = lm.fit(features_selected_train[final_columns], y_train)

# %%
features_selected_test = features_64_test[final_columns]
y_pred = lm.predict(features_selected_test)

print(metrics.mean_absolute_error(y_test, y_pred))
print(metrics.mean_squared_error(y_test, y_pred))
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 43.563693751028204
# 2968.1483447808664
# 54.480715347550884

# %% [markdown]
# # Embedded Methods
#
# Embedded methods learn which features best contribute to the accuracy of the model while the model is being created. The most common type of embedded feature selection methods are regularization methods.
#
# Regularization methods are also called penalization methods that introduce additional constraints into the optimization of a predictive algorithm (such as a regression algorithm) that bias the model toward lower complexity (fewer coefficients).
#
# Examples of regularization algorithms are the LASSO, Elastic Net and Ridge Regression.

# %% [markdown]
# ![alt text](Embedded_1.webp)
